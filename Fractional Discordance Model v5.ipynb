# %%
#! /usr/bin/env python
#  -*- coding: utf-8 -*-
#
# GUI module generated by PAGE version 4.20
#  in conjunction with Tcl version 8.6
#    May 29, 2019 01:55:26 PM MDT  platform: Windows NT
###############################################################################
###############################################################################
#need to add in
#import MODOAnalysis
import sys
import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.backends.backend_tkagg as tkagg
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
#from tkinter.filedialog import askopenfilename
#from tkinter.filedialog import asksaveasfile
from matplotlib.figure import Figure
import matplotlib.transforms
import warnings
warnings.simplefilter('ignore', np.RankWarning)
#import itertools
#from pykrige.uk import UniversalKriging
#from matplotlib.mlab import griddata

#from tkinter import *
###############################################################################
###############################################################################

global lambda68
global lambda75
global  u238_u235
global avagadro

lambda68=0.155125*10**-9
lambda75=0.98485*10**-9
u238_u235=137.88
avagadro=(6.0221409*10**23)

try:
    import Tkinter as tk
except ImportError:
    import tkinter as tk

try:
    import ttk
    py3 = False
except ImportError:
    import tkinter.ttk as ttk
    py3 = True

import dsicordance_gui_v1_support

def vp_start_gui():
    '''Starting point when module is the main routine.'''
    global val, w, root
    root = tk.Tk()
    top = Toplevel1 (root)
    dsicordance_gui_v1_support.init(root, top)
    root.mainloop()

w = None
def create_Toplevel1(root, *args, **kwargs):
    '''Starting point when module is imported by another program.'''
    global w, w_win, rt
    rt = root
    w = tk.Toplevel (root)
    top = Toplevel1 (w)
    dsicordance_gui_v1_support.init(w, top, *args, **kwargs)
    return (w, top)

def destroy_Toplevel1():
    global w
    w.destroy()
    w = None

class Toplevel1:
    def __init__(self, top=None):
        self.fig_canvas=None
        self.extra_206_loss=0
        self.extra_207_loss=0
        self.max_discordance=0
        self.sample_t=1*10**6
        self.fig=None
        self.ax=None
        self.t=np.linspace(0,5,501)
        self.t=self.t*10**9
        self.pb206_u238=np.e**(lambda68*self.t)-1
        self.pb207_u235=np.e**(lambda75*self.t)-1
        self.toolbar=None
        self.t_labels_t=self.t[::100]/(10**9)
        self.t_labels_x=self.pb207_u235[::100]-2.5
        self.t_labels_y=self.pb206_u238[::100]
        self.max_age=5*10**9
        self.x_max=140
        self.y_max=1.2
        self.min_age=0
        self.x_min=0
        self.y_min=0
        self.bottom_intercept=0
        self.top_intercept=0
        self.extra_207_excess=0
        self.min_discordance=0
        '''This class configures and populates the toplevel window.
           top is the toplevel containing window.'''
        _bgcolor = '#d9d9d9'  # X11 color: 'gray85'
        _fgcolor = '#000000'  # X11 color: 'black'
        _compcolor = '#d9d9d9' # X11 color: 'gray85'
        _ana1color = '#d9d9d9' # X11 color: 'gray85' 
        _ana2color = '#ececec' # Closest X11 color: 'gray92' 

        top.geometry("1042x751+458+132")
        top.title("DiscordanceViz")
        top.configure(background="#d9d9d9")
        self.frame = tk.Frame(top)
        self.Canvas1 = tk.Canvas(top)
        self.Canvas1.place(relx=0.221, rely=0.133, relheight=0.83
                , relwidth=0.742)
        self.Canvas1.configure(background="#d9d9d9")
        self.Canvas1.configure(borderwidth="2")
        self.Canvas1.configure(insertbackground="black")
        self.Canvas1.configure(relief='ridge')
        self.Canvas1.configure(selectbackground="#c4c4c4")
        self.Canvas1.configure(selectforeground="black")
        self.Canvas1.configure(width=773)

        self.Label1 = tk.Label(top, justify='left')
        self.Label1.place(relx=0.029, rely=0.01, height=21, width=97)
        self.Label1.configure(background="#d9d9d9")
        self.Label1.configure(disabledforeground="#a3a3a3")
        self.Label1.configure(foreground="#000000")
        self.Label1.configure(text='''Sample Age (Ma)''')
        
        
        self.Scale1 = tk.Scale(top, from_=1.0, to=4500.0, command=self.sample_age)
        self.Scale1.place(relx=0.029, rely=0.04, relwidth=0.175, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale1.configure(activebackground="#ececec")
        self.Scale1.configure(background="#d9d9d9")
        self.Scale1.configure(font="TkTextFont")
        self.Scale1.configure(foreground="#000000")
        self.Scale1.configure(highlightbackground="#d9d9d9")
        self.Scale1.configure(highlightcolor="black")
        self.Scale1.configure(length="176")
        self.Scale1.configure(orient="horizontal")
        self.Scale1.configure(tickinterval="1500.0")
        self.Scale1.configure(troughcolor="#d9d9d9")

        self.Label2 = tk.Label(top, justify='left')
        self.Label2.place(relx=0.029, rely=0.12, height=21, width=96)
        self.Label2.configure(background="#d9d9d9")
        self.Label2.configure(disabledforeground="#a3a3a3")
        self.Label2.configure(foreground="#000000")
        self.Label2.configure(text='''Max Discordance''')

        self.Scale2 = tk.Scale(top, from_=0, to=100, command=self.max_disc)
        self.Scale2.place(relx=0.029, rely=0.14, relwidth=0.102, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale2.configure(activebackground="#ececec")
        self.Scale2.configure(background="#d9d9d9")
        self.Scale2.configure(font="TkTextFont")
        self.Scale2.configure(foreground="#000000")
        self.Scale2.configure(highlightbackground="#d9d9d9")
        self.Scale2.configure(highlightcolor="black")
        self.Scale2.configure(orient="horizontal")
        self.Scale2.configure(tickinterval="100.0")
        self.Scale2.configure(troughcolor="#d9d9d9")

        self.label2_2 = tk.Label(top, justify='left')
        self.label2_2.place(relx=0.029, rely=0.23, height=21, width=96)
        self.label2_2.configure(background="#d9d9d9")
        self.label2_2.configure(disabledforeground="#a3a3a3")
        self.label2_2.configure(foreground="#000000")
        self.label2_2.configure(text='''Min Discordance''')

        self.scale2_2 = tk.Scale(top, from_=0, to=100, command=self.min_disc)
        self.scale2_2.place(relx=0.029, rely=0.25, relwidth=0.102, relheight=0.0
                , height=61, bordermode='ignore')
        self.scale2_2.configure(activebackground="#ececec")
        self.scale2_2.configure(background="#d9d9d9")
        self.scale2_2.configure(font="TkTextFont")
        self.scale2_2.configure(foreground="#000000")
        self.scale2_2.configure(highlightbackground="#d9d9d9")
        self.scale2_2.configure(highlightcolor="black")
        self.scale2_2.configure(orient="horizontal")
        self.scale2_2.configure(tickinterval="100.0")
        self.scale2_2.configure(troughcolor="#d9d9d9")





        self.Label3 = tk.Label(top, justify='left')
        self.Label3.place(relx=0.029, rely=0.34, height=21, width=105)
        self.Label3.configure(background="#d9d9d9")
        self.Label3.configure(disabledforeground="#a3a3a3")
        self.Label3.configure(foreground="#000000")
        self.Label3.configure(text='''Pb207 Loss''')




        self.Scale3 = tk.Scale(top, from_=0, to=100, command=self.scale_207)
        self.Scale3.place(relx=0.029, rely=0.37, relwidth=0.102, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale3.configure(activebackground="#ececec")
        self.Scale3.configure(background="#d9d9d9")
        self.Scale3.configure(font="TkTextFont")
        self.Scale3.configure(foreground="#000000")
        self.Scale3.configure(highlightbackground="#d9d9d9")
        self.Scale3.configure(highlightcolor="black")
        self.Scale3.configure(orient="horizontal")
        self.Scale3.configure(tickinterval="100.0")
        self.Scale3.configure(troughcolor="#d9d9d9")

        self.Label3_2 = tk.Label(top, justify='left')
        self.Label3_2.place(relx=0.029, rely=0.45, height=21, width=105)
        self.Label3_2.configure(activebackground="#f9f9f9")
        self.Label3_2.configure(activeforeground="black")
        self.Label3_2.configure(background="#d9d9d9")
        self.Label3_2.configure(disabledforeground="#a3a3a3")
        self.Label3_2.configure(foreground="#000000")
        self.Label3_2.configure(highlightbackground="#d9d9d9")
        self.Label3_2.configure(highlightcolor="black")
        self.Label3_2.configure(text='''Pb206 Loss''')

        self.Scale4 = tk.Scale(top, from_=0.0, to=100, command=self.scale_206)
        self.Scale4.place(relx=0.029, rely=0.47, relwidth=0.102, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale4.configure(activebackground="#ececec")
        self.Scale4.configure(background="#d9d9d9")
        self.Scale4.configure(font="TkTextFont")
        self.Scale4.configure(foreground="#000000")
        self.Scale4.configure(highlightbackground="#d9d9d9")
        self.Scale4.configure(highlightcolor="black")
        self.Scale4.configure(orient="horizontal")
        self.Scale4.configure(tickinterval="100.0")
        self.Scale4.configure(troughcolor="#d9d9d9")
                              
        self.Label3_2 = tk.Label(top, justify='left')
        self.Label3_2.place(relx=0.029, rely=0.57, height=21, width=105)
        self.Label3_2.configure(activebackground="#f9f9f9")
        self.Label3_2.configure(activeforeground="black")
        self.Label3_2.configure(background="#d9d9d9")
        self.Label3_2.configure(disabledforeground="#a3a3a3")
        self.Label3_2.configure(foreground="#000000")
        self.Label3_2.configure(highlightbackground="#d9d9d9")
        self.Label3_2.configure(highlightcolor="black")
        self.Label3_2.configure(text='''Pb207 Excess''')

        self.Scale4 = tk.Scale(top, from_=0.0, to=100, command=self.excess_207)
        self.Scale4.place(relx=0.029, rely=0.6, relwidth=0.102, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale4.configure(activebackground="#ececec")
        self.Scale4.configure(background="#d9d9d9")
        self.Scale4.configure(font="TkTextFont")
        self.Scale4.configure(foreground="#000000")
        self.Scale4.configure(highlightbackground="#d9d9d9")
        self.Scale4.configure(highlightcolor="black")
        self.Scale4.configure(orient="horizontal")
        self.Scale4.configure(tickinterval="100.0")
        self.Scale4.configure(troughcolor="#d9d9d9")


        self.Label4 = tk.Label(top, justify='left')
        self.Label4.place(relx=0.029, rely=0.69, height=21, width=105)
        self.Label4.configure(activebackground="#f9f9f9")
        self.Label4.configure(activeforeground="black")
        self.Label4.configure(background="#d9d9d9")
        self.Label4.configure(disabledforeground="#a3a3a3")
        self.Label4.configure(foreground="#000000")
        self.Label4.configure(highlightbackground="#d9d9d9")
        self.Label4.configure(highlightcolor="black")
        self.Label4.configure(text='''Plot Max Age''')
                              
                              
        self.Scale5 = tk.Scale(top, from_=0.0, to=5000, command=self.plt_max)
        self.Scale5.place(relx=0.029, rely=0.72, relwidth=0.18, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale5.configure(activebackground="#ececec")
        self.Scale5.configure(background="#d9d9d9")
        self.Scale5.configure(font="TkTextFont")
        self.Scale5.configure(foreground="#000000")
        self.Scale5.configure(highlightbackground="#d9d9d9")
        self.Scale5.configure(highlightcolor="black")
        self.Scale5.configure(orient="horizontal")
        self.Scale5.configure(tickinterval="1500.0")
        self.Scale5.configure(troughcolor="#d9d9d9")
                              
                              
        self.Label5 = tk.Label(top, justify='left')
        self.Label5.place(relx=0.029, rely=0.82, height=21, width=105)
        self.Label5.configure(activebackground="#f9f9f9")
        self.Label5.configure(activeforeground="black")
        self.Label5.configure(background="#d9d9d9")
        self.Label5.configure(disabledforeground="#a3a3a3")
        self.Label5.configure(foreground="#000000")
        self.Label5.configure(highlightbackground="#d9d9d9")
        self.Label5.configure(highlightcolor="black")
        self.Label5.configure(text='''Plot Min Age''')
                              
                              
        self.Scale6 = tk.Scale(top, from_=0.0, to=5000, command=self.plt_min)
        self.Scale6.place(relx=0.029, rely=0.85, relwidth=0.18, relheight=0.0
                , height=61, bordermode='ignore')
        self.Scale6.configure(activebackground="#ececec")
        self.Scale6.configure(background="#d9d9d9")
        self.Scale6.configure(font="TkTextFont")
        self.Scale6.configure(foreground="#000000")
        self.Scale6.configure(highlightbackground="#d9d9d9")
        self.Scale6.configure(highlightcolor="black")
        self.Scale6.configure(orient="horizontal")
        self.Scale6.configure(tickinterval="1500.0")
        self.Scale6.configure(troughcolor="#d9d9d9")
                              
        self.Quit = tk.Button(top, command=self.quitit)
        self.Quit.place(relx=0.005, rely=0.95, height=25, width=147)
        self.Quit.configure(background="#FF0000")
        self.Quit.configure(disabledforeground="#a3a3a3")
        self.Quit.configure(foreground="#000000")
        self.Quit.configure(highlightbackground="#d9d9d9")
        self.Quit.configure(highlightcolor="black")
        self.Quit.configure(pady="0")
        self.Quit.configure(takefocus="0")
        self.Quit.configure(text='''Quit''')
        
        self.plot()

    def quitit(self):
#        print(self.sample_t)
        root.quit()
        root.destroy()
        sys.exit("Script No Longer Running")
        
    def plot(self):
        if self.fig==None:
            self.fig=Figure()
        if self.ax==None:
            self.ax=self.fig.add_subplot(111)
        self.ax.cla()
        self.ax.plot(self.pb207_u235,self.pb206_u238, label='Concordia')

#        self.ax.scatter(grid_x,grid_y,s=50,marker='+',c='0',alpha=0.5,linewidth=1, label='Grid Locations')
#        self.preview_ax.set_aspect(aspect='equal')
        self.ax.set_title('Effect of Pb207 and Pb206 Fractionation on Concordia Plot')
        self.ax.set_ylabel(r'$\frac{{}^{206}Pb}{{}^{238}U}$', fontsize=16)
        self.ax.set_xlabel(r'$\frac{{}^{207}Pb}{{}^{235}U}$', fontsize=16)
        
        
        t_label=[x for x in self.t if x < self.max_age and x> self.min_age]

        n_skip=int(np.around(len(t_label)/4,0))
#        print(n_skip)
        
        self.t_labels_t=np.around(self.t[::n_skip]/(10**9),2)
        self.t_labels_x=self.pb207_u235[::n_skip]
        self.t_labels_y=self.pb206_u238[::n_skip]
        
        self.ax.plot(self.t_labels_x,self.t_labels_y,marker='o',
                     linestyle='none', markersize=22, mfc='1', mec='0', alpha=0.8)
        
        for x,y,s in zip(self.t_labels_x,self.t_labels_y,self.t_labels_t):
            self.ax.text(x,y,s, ha='center', va='center')        
        pb76=((1/u238_u235)*(np.e**(lambda75*self.sample_t)-1))/(np.e**(lambda68*self.sample_t)-1)
        u238_sample_est=int(np.around((1/238)*(10**-9)*avagadro,0))*10
        u238_sample=np.array([u238_sample_est]*11)
        pb206_sample_i=u238_sample*(np.e**(lambda68*self.sample_t)-1)
        
        d=np.linspace(start=-self.min_discordance,stop=-self.max_discordance,endpoint =True, num=11)
        t_86_d=(d+1)*self.sample_t
        sample_68_d=np.e**(lambda68*t_86_d)-1
        pb206_sample=u238_sample*sample_68_d
        pb207_sample=pb206_sample*pb76
        pb207_sample_i=pb206_sample_i*pb76
#        pb206_u238_sample
#        print(pb206_sample_i)
#        print(u238_sample)
#        print(self.max_discordance)
        
        
        u235_sample=pb207_sample_i/(np.e**(lambda75*self.sample_t)-1)
#        pb207_sample_i=u235_sample*(np.e**(lambda75*self.sample_t)-1)
#        print(pb76)
        standard_206_loss=pb206_sample_i-pb206_sample
#        pb206_sample+=standard_206_loss
#        pb207_sample_init=pb207_sample
#        pb207_sample=pb206_sample*pb76
        standard_207_loss=pb207_sample_i-pb207_sample
        
        
#        standard_206_loss=-min(pb206_sample)*self.max_discordance
#        pb206_sample+=standard_206_loss
#        pb207_sample_init=pb207_sample
#        pb207_sample=pb206_sample*pb76
#        standard_207_loss=pb207_sample_init-pb207_sample
#        
        
        
        pb206_u238_sample=pb206_sample/u238_sample
        pb207_u235_sample=pb207_sample/u235_sample
        
        t238=np.log(pb206_u238_sample+1)/lambda68
        t235=np.log(pb207_u235_sample+1)/lambda75
        discordance=t238/self.sample_t*100-100
        
        
        
#        pb206_test=(1-self.extra_206_loss)*pb206_sample   #old method
#        pb207_test=(1-self.extra_207_loss)*pb207_sample
        pb206_test=pb206_sample+self.extra_206_loss*standard_206_loss
        pb207_test=pb207_sample-self.extra_207_loss*standard_207_loss
        
        if self.extra_207_excess>0:pb207_test=pb207_sample*(1+self.extra_207_excess)
        
        pb206_u238_test=pb206_test/u238_sample
        pb207_u235_test=pb207_test/u235_sample
        
        poly_out=np.polyfit(pb207_u235_test,pb206_u238_test,1)
        m=poly_out[0]
        b=poly_out[1]
        
        
        
        def eq_1(x):
            return np.log(m*x+b+1)/np.log(x+1)
        
        
        def bottom_intercept():
            x_bar=np.max(pb207_u235_test)
            bottom_diff=3000000000
            i=0
            x=x_bar
        
            compare=lambda68/lambda75
            
            while x>0.0000000001:
                y=x*(1/2)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while x>0.0000000001:
                y=x*(3/4)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_2={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while x>0.0000000001:
                y=x*(6/7)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_3={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while x>0.0000000001:
                y=x*(8/9)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_4={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
            
            while x>0.0000000001:
                y=x*(99/100)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_5={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))

            while x>0.0000000001:
                y=x*(499/500)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_6={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
            
            while x>0.0000000001:
                y=x*(999/1000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while x>0.0000000001:
                y=x*(9999/10000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))

            while x>0.0000000001:
                y=x*(99999/100000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))

            while x>0.0000000001:
                y=x*(999999/1000000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                if i==0:print('{}:{}'.format(i,x1-x2))
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
            
#            while i<5000:
#                y=x-0.00000001
#                i+=1
#                try: 
#                    bottom_diff=compare-eq_1(y)
#
#                except: 
#                    print('oh stuff')
#                
#                if bottom_diff>0:
#                    x=y 
#                    print(x)
#                    
#                else:
#                    break
#                    
                                
            return x


        def top_intercept():
            i=0
            compare=lambda68/lambda75
            x=self.bottom_intercept
            
            
            while i<20:
                y=x/(1/2)
                i+=1
                bottom_diff=compare-eq_1(y)
#                print('i={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                if bottom_diff<0:
                    x=y
                else:
                    break
            
            
            while i<1000:
                y=x/(1/2)
                i+=1
                bottom_diff=compare-eq_1(y)
#                print('i={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                if bottom_diff>0:
                    x=y
                else:
                    break
                
                
            while i<1000:
                y=x/(3/4)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_2={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while i<1000:
                y=x/(6/7)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_3={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while i<1000:
                y=x/(8/9)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_4={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
            
            while i<1000:
                y=x/(99/100)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_5={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))

            while i<1000:
                y=x/(499/500)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_6={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
            
            while i<1000:
                y=x/(999/1000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            while i<1000:
                y=x/(9999/10000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))

            while i<1000:
                y=x/(99999/100000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))

            while i<1000:
                y=x/(999999/1000000)
                i+=1
                bottom_diff=compare-eq_1(y)
                if bottom_diff>0:
                    x=y
                else:
                    break
#                print('i_7={} /n x={} /n bottom_diff={}'.format(i,x,bottom_diff))
                
            return x        
        

        if self.max_discordance>0 :self.bottom_intercept= np.log(bottom_intercept()+1)/lambda75*1e-9
        
#        print(np.log(bottom_intercept()+1)/lambda75*1e-9)
        self.top_intercept= np.log(top_intercept()+1)/lambda75*1e-9   
#        print(self.top_intercept)
        
        new_76_age=pb207_test[-1]/pb206_test[-1]
        
        def age_76(new_76_age):
            t_test=1000
            i=0
            #global diff
            diff=100
            while np.abs(diff)>0.01 and i<2000:
                i+=1
                pb76_test=((1/u238_u235)*(np.e**(lambda75*t_test)-1))/(np.e**(lambda68*t_test)-1)
                diff=new_76_age-pb76_test
                if diff >0:
                    t_test+=100000000
                if diff <0:
                    t_test+=-100000000
        #        print ('{}. {}'.format(i,diff))
        #    print (diff)
            while np.abs(diff)>0.0001 and i<2000:
                i+=1
                pb76_test=((1/u238_u235)*(np.e**(lambda75*t_test)-1))/(np.e**(lambda68*t_test)-1)
                diff=new_76_age-pb76_test
                if diff >0:
                    t_test+=1000000
                if diff <0:
                    t_test+=-1000000
        #        print ('{}. {}'.format(i,diff))
            while np.abs(diff)>0.000001 and i<2000:
                i+=1
                pb76_test=((1/u238_u235)*(np.e**(lambda75*t_test)-1))/(np.e**(lambda68*t_test)-1)
                diff=new_76_age-pb76_test
                if diff >0:
                    t_test+=10000
                if diff <0:
                    t_test+=-10000
        #        print ('{}. {}'.format(i,diff))
            while np.abs(diff)>0.0000001 and i<2000:
                i+=1
                pb76_test=((1/u238_u235)*(np.e**(lambda75*t_test)-1))/(np.e**(lambda68*t_test)-1)
                diff=new_76_age-pb76_test
                if diff >0:
                    t_test+=1000
                if diff <0:
                    t_test+=-1000
        #        print ('{}. {}'.format(i,diff))
            return (t_test)
                
        x_fits=np.linspace(0,150,10)
        if self.extra_207_excess>0:  x_fits=np.linspace(0,150,10)
        y_fits=m*x_fits+b
        self.ax.plot(x_fits,y_fits,marker='None', color='purple')
        self.ax.scatter(pb207_u235_sample,pb206_u238_sample, label='Normal Discordance', c='g',alpha=0.5) 
        self.ax.scatter(pb207_u235_test,pb206_u238_test, label='Fractionated Discordance',c='purple',alpha=0.5) 
        self.ax.text(70,0.55, 'Sample 7/6 Age={:.3f} Ga'.format(int(self.sample_t)/10**9))
        self.ax.text(70,0.5, 'Observed 7/6 Age=Depends on Fraction')#{:.3f} Ga'.format(age_76(new_76_age)/10**9))
        self.ax.text(70,0.45, 'Lower Intercept={:.3f} Ga'.format(self.bottom_intercept))
        self.ax.text(70,0.4, 'Upper Intercept={:.3f} Ga'.format(self.top_intercept))
#        self.ax.text(80,0.65, 'Sample U238/Pb206 Age={:.3f} Ga'.format(int(t238)/10**9))
#        self.ax.text(80,0.6, 'Observed 7/6 Age={:.3f} Ga'.format(age_76(t238_apparant)/10**9))
        self.ax.set_ylim(self.y_min,self.y_max)
        self.ax.set_xlim(self.x_min,self.x_max)
        self.ax.legend(loc=4)
        
#        self.ax.text()
        
        if self.fig_canvas==None:
            self.fig_canvas =  FigureCanvasTkAgg(self.fig, master=self.Canvas1)        
        self.fig_canvas.get_tk_widget().pack()
        
        self.fig_canvas.draw()
        
        if self.toolbar==None:
            self.toolbar=tkagg.NavigationToolbar2Tk(self.fig_canvas, self.frame)
        self.toolbar.update()
        self.frame.place(relx=0.22, rely=0.08, relheight=0.05
                , relwidth=0.75)
        self.fig_canvas.get_tk_widget().pack(fill="both", expand=True)
        
        
        
        

    def sample_age(self,val):
        self.sample_t=int(val)*10**6
        self.plot()

    def max_disc(self,val):
        self.max_discordance=int(val)/100
        self.plot()
        
    def min_disc(self,val):
        self.min_discordance=int(val)/100
        self.plot()

    def scale_207(self,val):
        self.extra_207_loss=int(val)/100
        self.plot()

    def scale_206(self,val):
        self.extra_206_loss=int(val)/100
        self.plot()
        
    def excess_207(self,val):
        self.extra_207_excess=int(val)/100
        self.plot()
    
    def plt_max(self, val):
        self.max_age=int(val)*10**6
        self.x_max=np.e**(lambda75*self.max_age)-1
        self.y_max=np.e**(lambda68*self.max_age)-1
        self.plot()

    def plt_min(self, val):
        self.min_age=int(val)*10**6
        self.x_min=np.e**(lambda75*self.min_age)-1
        self.y_min=np.e**(lambda68*self.min_age)-1
        self.plot()
                              

if __name__ == '__main__':
    vp_start_gui()
# Out:
# C:\Users\bcubrich\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:428: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\bcubrich\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:696: RuntimeWarning: invalid value encountered in double_scalars
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Script No Longer Running
# C:\Users\bcubrich\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3275: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
